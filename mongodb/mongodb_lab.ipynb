# %% [markdown]
# # Setup

# %%
MONGODB_START_FROM_SCRATCH = True
DOCKER_INTERNAL_HOST = "host.docker.internal"
DOCKER_DNS = ["10.15.20.1"]

MONGODB_REPLICA_SET = "replica_set_0"
MONGODB_TOTAL_NODES = 3

MONGODB_NODE_IPS = ["10.15.20.35"] * MONGODB_TOTAL_NODES
MONGODB_NODE_NAMES = [f"mongodb-node-{i + 1}" for i in range(MONGODB_TOTAL_NODES)]
MONGODB_NODE_HOSTNAMES = [
    f"{MONGODB_NODE_NAMES[i]}.lvilla17.vpn.itam.mx" for i in range(MONGODB_TOTAL_NODES)
]
MONGODB_NODE_PORTS = [27010 + (i + 1) for i in range(0, MONGODB_TOTAL_NODES)]

MONGODB_WORKDIR = "/data/db"

MONGO_INITDB_ROOT_USERNAME = "admin"
MONGO_INITDB_ROOT_PASSWORD = "admin"
MONGO_INITDB_DATABASE = "admin"

# %%
import os
from pathlib import Path

LOCALHOST_WORKDIR = f"{os.path.join(os.path.relpath(Path.cwd()))}"
DOCKER_MOUNTDIR = os.path.join(LOCALHOST_WORKDIR, "mount")
MONGODB_LOCAL_CLUSTER_KEY_PATH = os.path.join(DOCKER_MOUNTDIR, "mongo-keyfile")

mount_path = Path(DOCKER_MOUNTDIR)
mount_path.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Create session

# %%
from pymongo import MongoClient

nodes_ports = [
    f"{MONGODB_NODE_HOSTNAMES[i]}:{MONGODB_NODE_PORTS[i]}"
    for i in range(MONGODB_TOTAL_NODES)
]
connection_string = (
    f"mongodb://{MONGO_INITDB_ROOT_USERNAME}:{MONGO_INITDB_ROOT_PASSWORD}@"
    f"{','.join(nodes_ports)}/"
    f"?replicaSet={MONGODB_REPLICA_SET}&authSource=admin&w=majority"
)
print(f"Connection URL: {connection_string}")

client = MongoClient(connection_string)

db = client["db"]
users_collection = db["users"]
# Out:
# Connection URL: mongodb://admin:admin@mongodb-node-1.lvilla17.vpn.itam.mx:27011,mongodb-node-2.lvilla17.vpn.itam.mx:27012,mongodb-node-3.lvilla17.vpn.itam.mx:27013/?replicaSet=replica_set_0&authSource=admin&w=majority

# %% [markdown]
# ### Insert

# %%
from faker import Faker

fake = Faker()

# %%
# %%timeit -n 2 -r 2
# -n 1: run only 2 loop
# -r 1: repeat only 2 time

import random

print("Generating batch...")

users_batch = [
    {
        "name": (
            fake.unique.name() if random.random() > 0.5 else fake.unique.name().upper()
        ),
        "email": fake.ascii_free_email(),
        "profile": {
            "job": fake.job(),
            "company": fake.company(),
            "location": {
                "lat": float(fake.latitude()),
                "lng": float(fake.longitude()),
            },
        },
        "tags": [fake.word() for _ in range(random.randint(2, 5))],
        "login_count": random.randint(1, 1000),
        "last_login": fake.date_time_this_year().isoformat(),
        "active": fake.boolean(chance_of_getting_true=75),
    }
    for _ in range(10000)
]
print("Inserting batch...")
users_collection.insert_many(users_batch)
# Out:
# Generating batch...
# Inserting batch...
# InsertManyResult([ObjectId('697836b1b54156c31b6a59c3'), ObjectId('697836b1b54156c31b6a59c4'), ObjectId('697836b1b54156c31b6a59c5'), ObjectId('697836b1b54156c31b6a59c6'), ObjectId('697836b1b54156c31b6a59c7'), ObjectId('697836b1b54156c31b6a59c8'), ObjectId('697836b1b54156c31b6a59c9'), ObjectId('697836b1b54156c31b6a59ca'), ObjectId('697836b1b54156c31b6a59cb'), ObjectId('697836b1b54156c31b6a59cc'), ObjectId('697836b1b54156c31b6a59cd'), ObjectId('697836b1b54156c31b6a59ce'), ObjectId('697836b1b54156c31b6a59cf'), ObjectId('697836b1b54156c31b6a59d0'), ObjectId('697836b1b54156c31b6a59d1'), ObjectId('697836b1b54156c31b6a59d2'), ObjectId('697836b1b54156c31b6a59d3'), ObjectId('697836b1b54156c31b6a59d4'), ObjectId('697836b1b54156c31b6a59d5'), ObjectId('697836b1b54156c31b6a59d6'), ObjectId('697836b1b54156c31b6a59d7'), ObjectId('697836b1b54156c31b6a59d8'), ObjectId('697836b1b54156c31b6a59d9'), ObjectId('697836b1b54156c31b6a59da'), ObjectId('697836b1b54156c31b6a59db'), ObjectId('697836b1b54156c31b6a59dc'), ObjectId('697836b1b54156c31b6a59dd'), ObjectId('697836b1b54156c31b6a59de'), ObjectId('697836b1b54156c31b6a59df'), ObjectId('697836b1b54156c31b6a59e0'), ObjectId('697836b1b54156c31b6a59e1'), ObjectId('697836b1b54156c31b6a59e2'), ObjectId('697836b1b54156c31b6a59e3'), ObjectId('697836b1b54156c31b6a59e4'), ObjectId('697836b1b54156c31b6a59e5'), ObjectId('697836b1b54156c31b6a59e6'), ObjectId('697836b1b54156c31b6a59e7'), ObjectId('697836b1b54156c31b6a59e8'), ObjectId('697836b1b54156c31b6a59e9'), ObjectId('697836b1b54156c31b6a59ea'), ObjectId('697836b1b54156c31b6a59eb'), ObjectId('697836b1b54156c31b6a59ec'), ObjectId('697836b1b54156c31b6a59ed'), ObjectId('697836b1b54156c31b6a59ee'), ObjectId('697836b1b54156c31b6a59ef'), ObjectId('697836b1b54156c31b6a59f0'), ObjectId('697836b1b54156c31b6a59f1'), ObjectId('697836b1b54156c31b6a59f2'), ObjectId('697836b1b54156c31b6a59f3'), ObjectId('697836b1b54156c31b6a59f4'), ObjectId('697836b1b54156c31b6a59f5'), ObjectId('697836b1b54156c31b6a59f6'), ObjectId('697836b1b54156c31b6a59f7'), ObjectId('697836b1b54156c31b6a59f8'), ObjectId('697836b1b54156c31b6a59f9'), ObjectId('697836b1b54156c31b6a59fa'), ObjectId('697836b1b54156c31b6a59fb'), ObjectId('697836b1b54156c31b6a59fc'), ObjectId('697836b1b54156c31b6a59fd'), ObjectId('697836b1b54156c31b6a59fe'), ObjectId('697836b1b54156c31b6a59ff'), ObjectId('697836b1b54156c31b6a5a00'), ObjectId('697836b1b54156c31b6a5a01'), ObjectId('697836b1b54156c31b6a5a02'), ObjectId('697836b1b54156c31b6a5a03'), ObjectId('697836b1b54156c31b6a5a04'), ObjectId('697836b1b54156c31b6a5a05'), ObjectId('697836b1b54156c31b6a5a06'), ObjectId('697836b1b54156c31b6a5a07'), ObjectId('697836b1b54156c31b6a5a08'), ObjectId('697836b1b54156c31b6a5a09'), ObjectId('697836b1b54156c31b6a5a0a'), ObjectId('697836b1b54156c31b6a5a0b'), ObjectId('697836b1b54156c31b6a5a0c'), ObjectId('697836b1b54156c31b6a5a0d'), ObjectId('697836b1b54156c31b6a5a0e'), ObjectId('697836b1b54156c31b6a5a0f'), ObjectId('697836b1b54156c31b6a5a10'), ObjectId('697836b1b54156c31b6a5a11'), ObjectId('697836b1b54156c31b6a5a12'), ObjectId('697836b1b54156c31b6a5a13'), ObjectId('697836b1b54156c31b6a5a14'), ObjectId('697836b1b54156c31b6a5a15'), ObjectId('697836b1b54156c31b6a5a16'), ObjectId('697836b1b54156c31b6a5a17'), ObjectId('697836b1b54156c31b6a5a18'), ObjectId('697836b1b54156c31b6a5a19'), ObjectId('697836b1b54156c31b6a5a1a'), ObjectId('697836b1b54156c31b6a5a1b'), ObjectId('697836b1b54156c31b6a5a1c'), ObjectId('697836b1b54156c31b6a5a1d'), ObjectId('697836b1b54156c31b6a5a1e'), ObjectId('697836b1b54156c31b6a5a1f'), ObjectId('697836b1b54156c31b6a5a20'), ObjectId('697836b1b54156c31b6a5a21'), ObjectId('697836b1b54156c31b6a5a22'), ObjectId('697836b1b54156c31b6a5a23'), ObjectId('697836b1b54156c31b6a5a24'), ObjectId('697836b1b54156c31b6a5a25'), ObjectId('697836b1b54156c31b6a5a26'), ObjectId('697836b1b54156c31b6a5a27'), ObjectId('697836b1b54156c31b6a5a28'), ObjectId('697836b1b54156c31b6a5a29'), ObjectId('697836b1b54156c31b6a5a2a'), ObjectId('697836b1b54156c31b6a ...

# %% [markdown]
# ### Query

# %%
query = {"active": True, "login_count": {"$gt": 500}}
results = users_collection.find(query)
print(f"Found {users_collection.count_documents(query)} highly active users.")
# Out:
# Found 3784 highly active users.

# %%
projection = {"name": 1, "email": 1, "profile.job": 1, "_id": 0}
cursor = users_collection.find({"tags": "work"}, projection).limit(100)
for user in cursor:
    print(user)
# Out:
# {'name': 'Joshua Washington', 'email': 'benjamin65@yahoo.com', 'profile': {'job': 'Museum/gallery exhibitions officer'}}
# {'name': 'DONALD SNYDER', 'email': 'jackgray@yahoo.com', 'profile': {'job': 'Merchandiser, retail'}}
# {'name': 'Dr. Thomas Norris', 'email': 'anthonywilliams@yahoo.com', 'profile': {'job': 'Intelligence analyst'}}
# {'name': 'PATRICIA ALLEN', 'email': 'nicholasjackson@hotmail.com', 'profile': {'job': 'Surveyor, minerals'}}
# {'name': 'Alexander Mitchell', 'email': 'michael60@hotmail.com', 'profile': {'job': 'Nurse, adult'}}
# {'name': 'GARY HAMILTON', 'email': 'stevensmichelle@gmail.com', 'profile': {'job': 'Pharmacist, community'}}
# {'name': 'JENNIFER STEIN', 'email': 'linda93@gmail.com', 'profile': {'job': 'Immunologist'}}
# {'name': 'JAIME PHELPS MD', 'email': 'sarah65@hotmail.com', 'profile': {'job': 'Sports administrator'}}
# {'name': 'VALERIE KING', 'email': 'benjaminhernandez@hotmail.com', 'profile': {'job': 'Health physicist'}}
# {'name': 'Regina Baker', 'email': 'teresamurphy@hotmail.com', 'profile': {'job': 'Database administrator'}}
# {'name': 'MARK NGUYEN', 'email': 'codyjones@hotmail.com', 'profile': {'job': 'Publishing copy'}}
# {'name': 'ANA CALHOUN', 'email': 'duffywilliam@gmail.com', 'profile': {'job': 'Programmer, systems'}}
# {'name': 'Stephen Williams', 'email': 'vdavis@gmail.com', 'profile': {'job': 'Therapeutic radiographer'}}
# {'name': 'AMY FRAZIER', 'email': 'george86@gmail.com', 'profile': {'job': 'Fitness centre manager'}}
# {'name': 'Thomas Vargas', 'email': 'wleonard@hotmail.com', 'profile': {'job': 'Commissioning editor'}}
# {'name': 'Tara Moore', 'email': 'mccormickamy@gmail.com', 'profile': {'job': 'Civil engineer, contracting'}}
# {'name': 'JOSHUA WHITE', 'email': 'deannaheath@gmail.com', 'profile': {'job': 'Copywriter, advertising'}}
# {'name': 'JENNIFER ROGERS', 'email': 'mmartin@hotmail.com', 'profile': {'job': 'Geographical information systems officer'}}
# {'name': 'Theresa Sanchez', 'email': 'robertchung@hotmail.com', 'profile': {'job': 'Statistician'}}
# {'name': 'Valerie Rogers', 'email': 'qdurham@hotmail.com', 'profile': {'job': 'Physiological scientist'}}
# {'name': 'Marc Dixon', 'email': 'robin63@yahoo.com', 'profile': {'job': 'IT consultant'}}
# {'name': 'KEVIN KELLY', 'email': 'lewiseric@yahoo.com', 'profile': {'job': 'Scientist, product/process development'}}
# {'name': 'LISA LAMBERT', 'email': 'bradfordaustin@hotmail.com', 'profile': {'job': 'Outdoor activities/education manager'}}
# {'name': 'Melanie Smith', 'email': 'mmosley@yahoo.com', 'profile': {'job': 'Product designer'}}
# {'name': 'April Baker', 'email': 'tlandry@hotmail.com', 'profile': {'job': 'Museum/gallery curator'}}
# {'name': 'TAMARA STEVENS', 'email': 'hallandrew@gmail.com', 'profile': {'job': 'Air traffic controller'}}
# {'name': 'JEFFREY SINGLETON', 'email': 'beckerashley@hotmail.com', 'profile': {'job': 'Journalist, magazine'}}
# {'name': 'JONATHAN DECKER', 'email': 'rrogers@hotmail.com', 'profile': {'job': 'Claims inspector/assessor'}}
# {'name': 'BONNIE BECK', 'email': 'ygonzalez@gmail.com', 'profile': {'job': 'Mudlogger'}}
# {'name': 'Melissa Lopez', 'email': 'danderson@yahoo.com', 'profile': {'job': 'Sub'}}
# {'name': 'NICHOLAS LANG', 'email': 'nicholas30@gmail.com', 'profile': {'job': 'Engineer, production'}}
# {'name': 'Ashley Phillips', 'email': 'kaylee69@hotmail.com', 'profile': {'job': 'Engineer, maintenance'}}
# {'name': 'AARON DOYLE', 'email': 'parkerkatie@hotmail.com', 'profile': {'job': 'Illustrator'}}
# {'name': 'Lynn Reed', 'email': 'pnelson@hotmail.com', 'profile': {'job': 'Photographer'}}
# {'name': 'PAIGE COLE', 'email': 'carpenterrandy@hotmail.com', 'profile': {'job': 'Town planner'}}
# {'name': 'CHRISTOPHER KHAN', 'email': 'james99@gmail.com', 'profile': {'job': 'Volunteer coordinator'}}
# {'name': 'CHRISTINA HOWARD', 'email': 'christopheryoung@gmail.com', 'profile': {'job': 'Data scientist'}}
# {'name': 'RACHEL STEVENSON', 'email': 'nicholas29@gmail.com', 'profile': {'job': 'Interior and spatial designer'}}
# {'name': 'Steven Romero', 'email': 'gharvey@yahoo.com', 'profile': {'job': 'Architect'}}
# {'name': 'Kyle Jackson', 'email': 'francisemma@gmail.com', 'profile': {'job': 'Musician'}}
# {'name': 'Jimmy Tyler', 'email': 'timothysutton@yahoo.com', 'profile': {'job': 'Surveyor, commercial/residential'}}
# {'name': 'Emily Mcguire', 'email': 'jessicasmith@yahoo.com', 'profile': {'job': 'Radio producer'}}
# {'name': 'Michael Serrano', 'email': 'vhughes@gmail.com', 'profile': {'job': 'Clinical research associate'}}
# {'name': 'JENNIFER MCDONALD', 'email': 'pearsonkathy@yahoo.com', 'profile': {'job': 'Amenity horticulturist'}}
# {'name': 'David Lin', 'email': 'terri57@hotmail.com', 'profile': {'job': 'Holiday representative'}}

# %%
pipeline = [
    {"$match": {"active": True}},  # Stage 1: Filter only active users
    {  # Stage 2: Group by the nested 'job' field
        "$group": {
            "_id": "$profile.job",
            "avg_logins": {"$avg": "$login_count"},
            "user_count": {"$sum": 1},
        }
    },
    {"$sort": {"avg_logins": -1}},  # Stage 3: Sort by average logins descending
    {
        "$project": {
            "_id": 0,  # Hide the original _id
            "job_title": "$_id",  # Rename _id to job_title
            "stats": {  # Create a nested object for stats
                "average": "$avg_logins",
                "total_users": "$user_count",
            },
        }
    },
    {"$limit": 100},  # Stage 4: Limit to top 100 most active professions
]
results = list(users_collection.aggregate(pipeline))
for res in results:
    print(res)
# Out:
# {'job_title': 'Prison officer', 'stats': {'average': 771.4, 'total_users': 10}}
# {'job_title': 'Community development worker', 'stats': {'average': 767.7142857142857, 'total_users': 7}}
# {'job_title': 'Ergonomist', 'stats': {'average': 750.7, 'total_users': 10}}
# {'job_title': 'Educational psychologist', 'stats': {'average': 735.2, 'total_users': 5}}
# {'job_title': 'Bonds trader', 'stats': {'average': 728.6363636363636, 'total_users': 11}}
# {'job_title': 'Engineer, agricultural', 'stats': {'average': 718.7692307692307, 'total_users': 13}}
# {'job_title': 'Gaffer', 'stats': {'average': 707.3333333333334, 'total_users': 6}}
# {'job_title': 'Geochemist', 'stats': {'average': 707.0, 'total_users': 6}}
# {'job_title': 'Farm manager', 'stats': {'average': 701.2727272727273, 'total_users': 11}}
# {'job_title': 'Medical illustrator', 'stats': {'average': 698.5555555555555, 'total_users': 9}}
# {'job_title': 'Engineer, mining', 'stats': {'average': 697.3, 'total_users': 10}}
# {'job_title': 'Building surveyor', 'stats': {'average': 692.4, 'total_users': 5}}
# {'job_title': 'Electronics engineer', 'stats': {'average': 691.8571428571429, 'total_users': 7}}
# {'job_title': 'Animator', 'stats': {'average': 685.6666666666666, 'total_users': 12}}
# {'job_title': 'Chartered public finance accountant', 'stats': {'average': 684.4, 'total_users': 10}}
# {'job_title': 'Counsellor', 'stats': {'average': 682.3333333333334, 'total_users': 9}}
# {'job_title': 'Engineer, structural', 'stats': {'average': 676.75, 'total_users': 8}}
# {'job_title': 'Writer', 'stats': {'average': 676.2, 'total_users': 15}}
# {'job_title': 'Astronomer', 'stats': {'average': 676.125, 'total_users': 8}}
# {'job_title': 'Production manager', 'stats': {'average': 675.0, 'total_users': 17}}
# {'job_title': 'Therapist, music', 'stats': {'average': 673.8888888888889, 'total_users': 9}}
# {'job_title': 'Human resources officer', 'stats': {'average': 671.8571428571429, 'total_users': 7}}
# {'job_title': 'Engineer, civil (contracting)', 'stats': {'average': 665.9090909090909, 'total_users': 11}}
# {'job_title': 'Journalist, newspaper', 'stats': {'average': 663.0, 'total_users': 12}}
# {'job_title': 'Ship broker', 'stats': {'average': 661.7333333333333, 'total_users': 15}}
# {'job_title': 'Investment analyst', 'stats': {'average': 659.4, 'total_users': 10}}
# {'job_title': 'Hospital doctor', 'stats': {'average': 658.5, 'total_users': 8}}
# {'job_title': 'Designer, blown glass/stained glass', 'stats': {'average': 658.1666666666666, 'total_users': 6}}
# {'job_title': 'Magazine features editor', 'stats': {'average': 656.6153846153846, 'total_users': 13}}
# {'job_title': 'Engineer, building services', 'stats': {'average': 654.4166666666666, 'total_users': 12}}
# {'job_title': 'Youth worker', 'stats': {'average': 654.1818181818181, 'total_users': 11}}
# {'job_title': 'Accountant, chartered certified', 'stats': {'average': 653.3636363636364, 'total_users': 11}}
# {'job_title': 'Retail buyer', 'stats': {'average': 651.7142857142857, 'total_users': 14}}
# {'job_title': 'Company secretary', 'stats': {'average': 649.4285714285714, 'total_users': 7}}
# {'job_title': 'Patent examiner', 'stats': {'average': 647.0909090909091, 'total_users': 11}}
# {'job_title': 'Geneticist, molecular', 'stats': {'average': 646.3333333333334, 'total_users': 12}}
# {'job_title': 'Radiographer, therapeutic', 'stats': {'average': 645.0, 'total_users': 13}}
# {'job_title': 'Office manager', 'stats': {'average': 644.3333333333334, 'total_users': 12}}
# {'job_title': 'Hotel manager', 'stats': {'average': 643.5, 'total_users': 8}}
# {'job_title': 'IT trainer', 'stats': {'average': 643.4285714285714, 'total_users': 7}}
# {'job_title': 'Data processing manager', 'stats': {'average': 642.3333333333334, 'total_users': 12}}
# {'job_title': 'Chartered certified accountant', 'stats': {'average': 640.6363636363636, 'total_users': 11}}
# {'job_title': 'Freight forwarder', 'stats': {'average': 639.9, 'total_users': 10}}
# {'job_title': 'Geographical information systems officer', 'stats': {'average': 638.9166666666666, 'total_users': 12}}
# {'job_title': 'Bookseller', 'stats': {'average': 634.0, 'total_users': 7}}
# {'job_title': 'Psychotherapist, child', 'stats': {'average': 633.6875, 'total_users': 16}}
# {'job_title': 'Probation officer', 'stats': {'average': 631.8, 'total_users': 10}}
# {'job_title': 'Nurse, adult', 'stats': {'average': 631.7777777777778, 'total_users': 9}}
# {'job_title': 'Photographer', 'stats': {'average': 631.625, 'total_users': 8}}
# {'job_title': 'Analytical chemist', 'stats': {'average': 631.5, 'total_users': 10}}
# {'job_title': 'Designer, fashion/clothing', 'stats': {'average': 630.3, 'total_users': 10}}
# {'job_title': 'Biomedical scientist', 'stats': {'average': 629.8888888888889, 'total_users': 9}}
# {'job_title': 'Catering manager', 'stats': {'average': 628.8181818181819, 'total_users': 11}}
# {'job_title': 'Brewing technologist', 'stats': {'average': 627.75, 'total_users': 8}}
# {'job_title': 'Field seismologist', 'stats': {'average': 627.7272727272727, 'total_users': 11}}
# {'job_title': 'Dancer', 'stats': {'average': 627.5, 'total_users': 10}}
# {'job_title': 'Paediatric nurse', 'stats': {'average': 626.5, 'total_users': 12}}
# {'job_title': 'Teacher, secondary school', 'stats': {'average': 620.4166666666666, 'total_users': 12}}
# {'job_title': 'Geologist, wellsite', 'stats': {'average': 619.8571428571429, 'total_users': 7}}
# {'job_title': 'Radio broadcast assistant', 'stats': {'average': 619.625, 'total_users': 8}}
# {'job_title': 'Police officer', 'stats': {'average': 619.5, 'total_users': 14}}
# {'job_title': 'Film/video editor', 'stats': {'average': 617.7, 'total_users': 10}}
# {'job_title': 'Psychologist, prison and probation services', 'stats': {'average': 616.0, 'total_users': 9}}
# {'job_title': 'Medical secretary', 'stats': {'average': 615.6666666666666, 'total_users': 9}}
# {'job_title': 'Arts development officer', 'stats': {'average': 615.3846153846154, 'total_users': 13}}
# {'job_title': 'Race relations officer', 'stats': {'average': 615.375, 'total_users': 8}}
# {'job_title': 'Designer, graphic', 'stats': {'average': 614.4, 'total_users': 10}}
# {'job_title': 'Corporate treasurer', 'stats': {'average': 613.8181818181819, 'total_users': 11}}
# {'job_title': 'Tour manager', 'stats': {'average': 613.6666666666666, 'total_users': 18}}
# {'job_title': 'Sports development officer', 'stats': {'average': 613.125, 'total_users': 8}}
# {'job_title': 'Equality and diversity officer', 'stats': {'average': 611.75, 'total_users': 4}}
# {'job_title': 'Environmental education officer', 'stats': {'average': 609.625, 'total_users': 8}}
# {'job_title': 'Dietitian', 'stats': {'average': 609.0769230769231, 'total_users': 13}}
# {'job_title': 'Surveyor, rural practice', 'stats': {'average': 608.6666666666666, 'total_users': 6}}
# {'job_title': 'Therapist, drama', 'stats': {'average': 607.4, 'total_users': 10}}
# {'job_title': 'Engineer, civil (consulting)', 'stats': {'average': 607.0, 'total_users': 14}}
# {'job_title': 'Health physicist', 'stats': {'average': 605.5833333333334, 'total_users': 12}}
# {'job_title': 'Diplomatic Services operational officer', 'stats': {'average': 605.0, 'total_users': 7}}
# {'job_title': 'Banker', 'stats': {'average': 603.6, 'total_users': 10}}
# {'job_title': 'Accountant, chartered', 'stats': {'average': 603.3333333333334, 'total_users': 15}}
# {'job_title': 'Legal secretary', 'stats': {'average': 603.3076923076923, 'total_users': 13}}
# {'job_title': 'Copy', 'stats': {'average': 602.6, 'total_users': 15}}
# {'job_title': 'Sales executive', 'stats': {'average': 602.4545454545455, 'total_users': 11}}
# {'job_title': 'Recycling officer', 'stats': {'average': 602.4444444444445, 'total_users': 9}}
# {'job_title': 'Barista', 'stats': {'average': 602.4375, 'total_users': 16}}
# {'job_title': 'Social researcher', 'stats': {'average': 602.0769230769231, 'total_users': 13}}
# {'job_title': 'Advertising copywriter', 'stats': {'average': 601.6923076923077, 'total_users': 13}}
# {'job_title': 'Civil Service fast streamer', 'stats': {'average': 601.2631578947369, 'total_users': 19}}
# {'job_title': 'Acupuncturist', 'stats': {'average': 600.375, 'total_users': 8}}
# {'job_title': 'Production assistant, television', 'stats': {'average': 600.2857142857143, 'total_users': 14}}
# {'job_title': 'Exhibitions officer, museum/gallery', 'stats': {'average': 599.875, 'total_users': 8}}
# {'job_title': 'Engineer, manufacturing', 'stats': {'average': 599.75, 'total_users': 8}}
# {'job_title': 'Psychiatric nurse', 'stats': {'average': 596.9285714285714, 'total_users': 14}}
# {'job_title': 'Scientist, physiological', 'stats': {'average': 596.5, 'total_users': 8}}
# {'job_title': 'Horticultural consultant', 'stats': {'average': 596.0, 'total_users': 5}}
# {'job_title': 'Airline pilot', 'stats': {'average': 595.8, 'total_users': 15}}
# {'job_title': 'Armed forces logistics/support/administrative officer', 'stats': {'average': 594.6875, 'total_users': 16}}
# {'job_title': 'Psychotherapist, dance movement', 'stats': {'average': 594.375, 'total_users': 8}}
# {'job_title': 'Commercial horticulturist', 'stats': {'average': 594.0, 'total_users': 11}}
# {'job_title': 'Cartographer', 'stats': {'average': 593.1818181818181, 'total_users': 11}}

# %%
northern_users = users_collection.count_documents({"profile.location.lat": {"$gt": 0}})
print(f"Users in Northern Hemisphere: {northern_users}")
# Out:
# Users in Northern Hemisphere: 5034

# %%
# Standard Sort (Z-A-a-z) vs. Collation Sort (A-a-B-b...)
cursor = users_collection.find({}).sort("name", 1).collation({"locale": "en", "strength": 2}).limit(100)

for user in cursor:
    print(user["name"])
# Out:
# AARON ACOSTA
# AARON BELL
# AARON BURGESS
# AARON CHAMBERS
# Aaron Cooper
# AARON DECKER
# AARON DIAZ
# Aaron Dominguez
# AARON DOYLE
# AARON FERRELL
# Aaron Garcia
# Aaron Gould
# Aaron Harper
# Aaron Holden
# Aaron Howard
# Aaron Johnson
# AARON KELLY
# AARON KIM
# Aaron Larson
# Aaron Long
# Aaron Martinez
# Aaron Meadows
# Aaron Moore
# Aaron Murphy
# AARON NAVARRO
# Aaron Olson
# AARON ORTIZ
# AARON PIERCE
# AARON POOLE
# AARON RIDDLE
# AARON SANCHEZ
# Aaron Terry
# AARON THOMAS
# AARON WAGNER
# AARON WILLIAMSON
# Aaron Wright
# ABIGAIL BEASLEY
# Abigail Bernard
# Abigail Dougherty
# ABIGAIL DOYLE
# Abigail Gregory
# Abigail Hawkins
# Abigail Heath
# ABIGAIL HERNANDEZ
# Abigail Holloway
# ABIGAIL MCCARTHY
# Abigail Mercer
# ABIGAIL PALMER
# Abigail Stanton
# ADAM BAKER
# ADAM BATES
# ADAM BRADFORD
# Adam Brown
# ADAM BURTON
# Adam Cannon
# ADAM CARTER
# Adam Coffey
# Adam Coleman
# ADAM COX
# ADAM DIXON
# ADAM FLORES
# Adam Fritz
# ADAM GONZALES
# ADAM GRIFFIN
# ADAM HAYDEN
# ADAM HOLLAND
# ADAM HORNE
# Adam Hughes
# Adam Landry
# Adam Martin
# Adam Meza
# Adam Mitchell
# Adam Morales
# ADAM MORGAN
# Adam Nelson
# Adam Perez
# Adam Peterson
# ADAM PIERCE
# Adam Ponce
# ADAM RASMUSSEN
# Adam Ruiz
# Adam Sanchez
# Adam Sanders
# Adam Scott
# Adam Smith
# ADAM THOMAS
# ADAM TREVINO JR.
# ADAM VALENTINE
# Adam Walker
# ADAM WALTON
# ADAM WEST JR.
# ADAM WILLIAMS
# ADAM WILSON
# ADAM WRIGHT
# ADAM ZAMORA
# ADRIAN CARR
# ADRIAN DAVIS
# Adrian Farmer
# Adrian Fernandez
# Adrian Harris

# %% [markdown]
# ### Update

# %%
# 1. Get a single user to test with
target_user = users_collection.find_one({"active": True})
user_id = target_user["_id"]
initial_logins = target_user.get("login_count", 0)

print(f"User: {target_user['name']}")
print(f"Initial login count: {initial_logins}")

# 2. Increment the login counter for JUST this user
users_collection.update_one(
    {"_id": user_id}, 
    {"$inc": {"login_count": 1}}
)

# 3. Query again to see the change
updated_user = users_collection.find_one({"_id": user_id})
new_logins = updated_user.get("login_count", 0)

print(f"Updated login count: {new_logins}")
print(f"Change confirmed: {new_logins == initial_logins + 1}")
# Out:
# User: DENNIS JONES
# Initial login count: 332
# Updated login count: 333
# Change confirmed: True

# %%
from pymongo import ReturnDocument

# This performs the update and returns the NEW version of the document immediately
updated_doc = users_collection.find_one_and_update(
    {"_id": user_id},
    {"$inc": {"login_count": 1}},
    return_document=ReturnDocument.AFTER
)

print(f"New count from single-step operation: {updated_doc['login_count']}")
# Out:
# New count from single-step operation: 334

# %%
query = {"profile.job": {"$regex": ".*engineer.*", "$options": "i"}}
update = {"$set": {"is_technical": True}}
result = users_collection.update_many(query, update)
print(f"Updated {result.modified_count} engineers.")
# Out:
# Updated 963 engineers.

# %%
query = {"email": "example@user.com"}
new_values = {"$set": {"active": False}}
users_collection.update_one(query, new_values)
# Out:
# UpdateResult({'n': 0, 'electionId': ObjectId('7fffffff0000000000000002'), 'opTime': {'ts': Timestamp(1769486007, 966), 't': 2}, 'nModified': 0, 'ok': 1.0, 'updatedExisting': False}, acknowledged=True)

# %% [markdown]
# ### Delete

# %%
delete_result = users_collection.delete_many({})
print(f"Deleted {delete_result.deleted_count} documents.")
# Out:
# Deleted 10000 documents.

# %%
db.drop_collection(users_collection)
print("Deleted users collection.")
# Out:
# Deleted users collection.
