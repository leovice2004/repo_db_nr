# %% [markdown]
# # Setup

# %%
MONGODB_START_FROM_SCRATCH = True
DOCKER_INTERNAL_HOST = "host.docker.internal"
DOCKER_DNS = ["10.15.20.1"]

MONGODB_REPLICA_SET = "replica_set_0"
MONGODB_TOTAL_NODES = 3

MONGODB_NODE_IPS = ["10.15.20.35"] * MONGODB_TOTAL_NODES
MONGODB_NODE_NAMES = [f"mongodb-node-{i + 1}" for i in range(MONGODB_TOTAL_NODES)]
MONGODB_NODE_HOSTNAMES = [
    f"{MONGODB_NODE_NAMES[i]}.lvilla17.vpn.itam.mx" for i in range(MONGODB_TOTAL_NODES)
]
MONGODB_NODE_PORTS = [27010 + (i + 1) for i in range(0, MONGODB_TOTAL_NODES)]

MONGODB_WORKDIR = "/data/db"

MONGO_INITDB_ROOT_USERNAME = "admin"
MONGO_INITDB_ROOT_PASSWORD = "admin"
MONGO_INITDB_DATABASE = "admin"

# %%
import os
from pathlib import Path

LOCALHOST_WORKDIR = f"{os.path.join(os.path.relpath(Path.cwd()))}"
DOCKER_MOUNTDIR = os.path.join(LOCALHOST_WORKDIR, "mount")
MONGODB_LOCAL_CLUSTER_KEY_PATH = os.path.join(DOCKER_MOUNTDIR, "mongo-keyfile")

mount_path = Path(DOCKER_MOUNTDIR)
mount_path.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# # Stop mongodb-cluster.docker-compose.yml

# %%
# !docker compose -f mongodb-cluster.docker-compose.yml down -v
# Out:
# open /Users/leonardovillarrealcerda/Documents/ITAM/ITAM_Semestre6/repo_db_nr/mongodb/mongodb-cluster.docker-compose.yml: no such file or directory

# %%
import shutil
import stat

if MONGODB_START_FROM_SCRATCH:
    if os.path.exists(MONGODB_LOCAL_CLUSTER_KEY_PATH):
        os.chmod(MONGODB_LOCAL_CLUSTER_KEY_PATH, stat.S_IWRITE)
    shutil.rmtree(DOCKER_MOUNTDIR)
    Path(DOCKER_MOUNTDIR).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# # Start mongodb-cluster.docker-compose.yml

# %%
import os
import stat
import yaml
import base64
import secrets
from IPython.display import Markdown, display

if not os.path.exists(MONGODB_LOCAL_CLUSTER_KEY_PATH):
    with open(MONGODB_LOCAL_CLUSTER_KEY_PATH, "w") as f:
        raw_data = secrets.token_bytes(756)
        f.write(base64.b64encode(raw_data).decode("utf-8"))

mongodb_compose_dict = {
    "name": "mongodb-cluster",
    "services": {},
    "networks": {"mongo-cluster": {"driver": "bridge"}},
}

for i in range(MONGODB_TOTAL_NODES):
    mongodb_compose_dict["services"][MONGODB_NODE_NAMES[i]] = {
        "image": "mongo:7.0",
        "container_name": MONGODB_NODE_NAMES[i],
        "hostname": MONGODB_NODE_HOSTNAMES[i],
        "command": [
            "bash",
            "-c",
            " && ".join(
                [
                    "chown 999:999 /data/configdb/keyfile",
                    "chmod 400 /data/configdb/keyfile",
                    " ".join(
                        [
                            "exec",
                            "docker-entrypoint.sh",
                            "mongod",
                            "--replSet",
                            MONGODB_REPLICA_SET,
                            "--keyFile",
                            "/data/configdb/keyfile",
                            "--bind_ip_all",
                            "--port",
                            f"{MONGODB_NODE_PORTS[i]}",
                        ]
                    ),
                ]
            ),
        ],
        "environment": [
            f"MONGO_INITDB_ROOT_USERNAME={MONGO_INITDB_ROOT_USERNAME}",
            f"MONGO_INITDB_ROOT_PASSWORD={MONGO_INITDB_ROOT_PASSWORD}",
            f"MONGO_INITDB_DATABASE={MONGO_INITDB_DATABASE}",
        ],
        "volumes": [
            f"{os.path.join(DOCKER_MOUNTDIR, MONGODB_NODE_NAMES[i])}:/data/db",
            f"{os.path.join(DOCKER_MOUNTDIR, 'mongo-keyfile')}:/data/configdb/keyfile",
        ],
        "networks": ["mongo-cluster"],
        "ports": [f"{MONGODB_NODE_PORTS[i]}:{MONGODB_NODE_PORTS[i]}"],
        "extra_hosts": [f"{DOCKER_INTERNAL_HOST}:host-gateway"],
        "dns": DOCKER_DNS,
        "deploy": {"resources": {"limits": {"cpus": "1.0", "memory": "1024M"}}},
        "healthcheck": {
            "test": [
                "CMD",
                "mongosh",
                "--port",
                f"{MONGODB_NODE_PORTS[i]}",
                "--quiet",
                "--eval",
                "db.adminCommand('ping')",
            ],
            "interval": "10s",
            "timeout": "10s",
            "retries": 30,
            "start_period": "30s",
        },
        "depends_on": {
            MONGODB_NODE_NAMES[j]: {"condition": "service_started"} for j in range(0, i)
        },
    }

mongodb_compose_yaml_path = os.path.join(
    LOCALHOST_WORKDIR, "mongodb-cluster.docker-compose.yml"
)
mongodb_compose_yaml_contents = yaml.dump(
    mongodb_compose_dict, default_flow_style=False, sort_keys=False, indent=4
)
with open(mongodb_compose_yaml_path, "w") as f:
    f.write(mongodb_compose_yaml_contents)

(print(f"Successfully created: '{os.path.relpath(mongodb_compose_yaml_path)}'"),)
display(Markdown(f"```yaml\n{mongodb_compose_yaml_contents}\n```"))
# Out:
# Successfully created: 'mongodb-cluster.docker-compose.yml'
# ```yaml
# name: mongodb-cluster
# services:
#     mongodb-node-1:
#         image: mongo:7.0
#         container_name: mongodb-node-1
#         hostname: mongodb-node-1.lvilla17.vpn.itam.mx
#         command:
#         - bash
#         - -c
#         - chown 999:999 /data/configdb/keyfile && chmod 400 /data/configdb/keyfile
#             && exec docker-entrypoint.sh mongod --replSet replica_set_0 --keyFile
#             /data/configdb/keyfile --bind_ip_all --port 27011
#         environment:
#         - MONGO_INITDB_ROOT_USERNAME=admin
#         - MONGO_INITDB_ROOT_PASSWORD=admin
#         - MONGO_INITDB_DATABASE=admin
#         volumes:
#         - ./mount/mongodb-node-1:/data/db
#         - ./mount/mongo-keyfile:/data/configdb/keyfile
#         networks:
#         - mongo-cluster
#         ports:
#         - 27011:27011
#         extra_hosts:
#         - host.docker.internal:host-gateway
#         dns: &id001
#         - 10.15.20.1
#         deploy:
#             resources:
#                 limits:
#                     cpus: '1.0'
#                     memory: 1024M
#         healthcheck:
#             test:
#             - CMD
#             - mongosh
#             - --port
#             - '27011'
#             - --quiet
#             - --eval
#             - db.adminCommand('ping')
#             interval: 10s
#             timeout: 10s
#             retries: 30
#             start_period: 30s
#         depends_on: {}
#     mongodb-node-2:
#         image: mongo:7.0
#         container_name: mongodb-node-2
#         hostname: mongodb-node-2.lvilla17.vpn.itam.mx
#         command:
#         - bash
#         - -c
#         - chown 999:999 /data/configdb/keyfile && chmod 400 /data/configdb/keyfile
#             && exec docker-entrypoint.sh mongod --replSet replica_set_0 --keyFile
#             /data/configdb/keyfile --bind_ip_all --port 27012
#         environment:
#         - MONGO_INITDB_ROOT_USERNAME=admin
#         - MONGO_INITDB_ROOT_PASSWORD=admin
#         - MONGO_INITDB_DATABASE=admin
#         volumes:
#         - ./mount/mongodb-node-2:/data/db
#         - ./mount/mongo-keyfile:/data/configdb/keyfile
#         networks:
#         - mongo-cluster
#         ports:
#         - 27012:27012
#         extra_hosts:
#         - host.docker.internal:host-gateway
#         dns: *id001
#         deploy:
#             resources:
#                 limits:
#                     cpus: '1.0'
#                     memory: 1024M
#         healthcheck:
#             test:
#             - CMD
#             - mongosh
#             - --port
#             - '27012'
#             - --quiet
#             - --eval
#             - db.adminCommand('ping')
#             interval: 10s
#             timeout: 10s
#             retries: 30
#             start_period: 30s
#         depends_on:
#             mongodb-node-1:
#                 condition: service_started
#     mongodb-node-3:
#         image: mongo:7.0
#         container_name: mongodb-node-3
#         hostname: mongodb-node-3.lvilla17.vpn.itam.mx
#         command:
#         - bash
#         - -c
#         - chown 999:999 /data/configdb/keyfile && chmod 400 /data/configdb/keyfile
#             && exec docker-entrypoint.sh mongod --replSet replica_set_0 --keyFile
#             /data/configdb/keyfile --bind_ip_all --port 27013
#         environment:
#         - MONGO_INITDB_ROOT_USERNAME=admin
#         - MONGO_INITDB_ROOT_PASSWORD=admin
#         - MONGO_INITDB_DATABASE=admin
#         volumes:
#         - ./mount/mongodb-node-3:/data/db
#         - ./mount/mongo-keyfile:/data/configdb/keyfile
#         networks:
#         - mongo-cluster
#         ports:
#         - 27013:27013
#         extra_hosts:
#         - host.docker.internal:host-gateway
#         dns: *id001
#         deploy:
#             resources:
#                 limits:
#                     cpus: '1.0'
#                     memory: 1024M
#         healthcheck:
#             test:
#             - CMD
#             - mongosh
#             - --port
#             - '27013'
#             - --quiet
#             - --eval
#             - db.adminCommand('ping')
#             interval: 10s
#             timeout: 10s
#             retries: 30
#             start_period: 30s
#         depends_on:
#             mongodb-node-1:
#                 condition: service_started
#             mongodb-node-2:
#                 condition: service_started
# networks:
#     mongo-cluster:
#         driver: bridge
#
# ```

# %%
# !docker compose -f mongodb-cluster.docker-compose.yml up -d --wait
# Out:
# [+] up 0/1
#  ⠋ Image mongo:7.0 Pulling                                                 0.1s
# [+] up 0/1
#  ⠙ Image mongo:7.0 Pulling                                                 0.2s
# [+] up 0/1
#  ⠹ Image mongo:7.0 Pulling                                                 0.3s
# [+] up 0/1
#  ⠸ Image mongo:7.0 Pulling                                                 0.4s
# [+] up 0/1
#  ⠼ Image mongo:7.0 Pulling                                                 0.5s
# [+] up 0/1
#  ⠴ Image mongo:7.0 Pulling                                                 0.6s
# [+] up 0/1
#  ⠦ Image mongo:7.0 Pulling                                                 0.7s
# [+] up 0/1
#  ⠧ Image mongo:7.0 Pulling                                                 0.8s
# [+] up 0/1
#  ⠇ Image mongo:7.0 Pulling                                                 0.9s
# [+] up 0/1
#  ⠏ Image mongo:7.0 Pulling                                                 1.0s
# [+] up 0/1
#  ⠋ Image mongo:7.0 Pulling                                                 1.1s
# [+] up 0/1
#  ⠙ Image mongo:7.0 Pulling                                                 1.2s
# [+] up 0/1
#  ⠹ Image mongo:7.0 Pulling                                                 1.3s
# [+] up 0/1
#  ⠸ Image mongo:7.0 Pulling                                                 1.4s
# [+] up 0/1
#  ⠼ Image mongo:7.0 Pulling                                                 1.5s
# [+] up 0/1
#  ⠴ Image mongo:7.0 Pulling                                                 1.6s
# [+] up 0/1
#  ⠦ Image mongo:7.0 Pulling                                                 1.7s
# [+] up 0/1
#  ⠧ Image mongo:7.0 Pulling                                                 1.8s
# [+] up 0/1
#  ⠇ Image mongo:7.0 Pulling                                                 1.9s
# [+] up 0/1
#  ⠏ Image mongo:7.0 Pulling                                                 2.0s
# [+] up 0/1
#  ⠋ Image mongo:7.0 Pulling                                                 2.1s
# [+] up 0/1
#  ⠙ Image mongo:7.0 Pulling                                                 2.2s
# [+] up 0/1
#  ⠹ Image mongo:7.0 Pulling                                                 2.3s
# [+] up 0/1
#  ⠸ Image mongo:7.0 Pulling                                                 2.4s
# [+] up 0/1
#  ⠼ Image mongo:7.0 Pulling                                                 2.5s
# [+] up 0/1
#  ⠴ Image mongo:7.0 Pulling                                                 2.6s
# [+] up 0/1
#  ⠦ Image mongo:7.0 Pulling                                                 2.7s
# [+] up 0/1
#  ⠧ Image mongo:7.0 Pulling                                                 2.8s
# [+] up 0/1
#  ⠇ Image mongo:7.0 Pulling                                                 2.9s
# [+] up 0/1
#  ⠏ Image mongo:7.0 Pulling                                                 3.0s
# [+] up 0/1
#  ⠋ Image mongo:7.0 Pulling                                                 3.1s
# [+] up 0/1
#  ⠙ Image mongo:7.0 Pulling                                                 3.2s
# [+] up 0/1
#  ⠹ Image mongo:7.0 Pulling                                                 3.3s
# [+] up 0/1
#  ⠸ Image mongo:7.0 Pulling                                                 3.4s
# [+] up 0/1
#  ⠼ Image mongo:7.0 Pulling                                                 3.5s
# [+] up 0/1
#  ⠴ Image mongo:7.0 Pulling                                                 3.6s
# [+] up 0/1
#  ⠦ Image mongo:7.0 Pulling                                                 3.7s
# [+] up 0/1
#  ⠧ Image mongo:7.0 Pulling                                                 3.8s
# [+] up 0/1
#  ⠇ Image mongo:7.0 Pulling                                                 3.9s
# [+] up 0/1
#  ⠏ Image mongo:7.0 Pulling                                                 4.0s
# [+] up 0/1
#  ⠋ Image mongo:7.0 Pulling                                                 4.1s
# [+] up 0/1
#  ⠙ Image mongo:7.0 Pulling                                                 4.2s
# [+] up 0/1
#  ⠹ Image mongo:7.0 Pulling                                                 4.3s
# [+] up 0/9
#  ⠸ Image mongo:7.0 [⠀⠀⠀⠀⠀⠀⠀⠀] Pulling                                      4.4s
#    ⠋ 517f43312bfe  Pulling fs layer                                        0.1s
#    ⠋ 97e87ddfd658  Pulling fs layer                                        0.1s
#    ⠋ 2f6342326cfb  Pulling fs layer                                        0.1s
#    ⠋ a6dbcc125dc3  Pulling fs layer                                        0.1s
#    ⠋ f22640b02e8e  Pulling fs layer                                        0.1s
#    ⠋ d95b4d4c57a3  Pulling fs layer                                        0.1s
#    ⠋ 25c011418e0e  Pulling fs layer                                        0.1s
#    ⠋ 0a02f680d534  Pulling fs layer                                        0.1s
# [+] up 0/9
#  ⠼ Image mongo:7.0 [⠀⠀⠀⠀⠀⠀⠀⠀] Pulling                                      4.5s
#    ⠙ 517f43312bfe  Pulling fs layer                                        0.2s
#    ⠙ 97e87ddfd658  Pulling fs layer                                        0.2s
#    ⠙ 2f6342326cfb  Pulling fs layer                                        0.2s
#    ⠙ a6dbcc125dc3  Pulling fs layer                                        0.2s
#    ⠙ f22640b02e8e  Pulling fs layer                                        0.2s
#    ⠙ d95b4d4c57a3  Pulling fs layer                                        0.2s
#    ⠙ 25c011418e0e  Pulling fs layer                                        0.2s
#    ⠙ 0a02f680d534  Pulling fs layer                                        0.2s
# [+] up 1/10
#  ⠴ Image mongo:7.0 [⠀⠀⠀⠀⠀⠀⠀⠀⣿] Pulling                                     4.6s
#    ⠹ 517f43312bfe  Pulling fs layer                                        0.3s
#    ⠹ 97e87ddfd658  Pulling fs layer                                        0.3s
#    ⠹ 2f6342326cfb  Pulling fs layer                                        0.3s
#    ⠹ a6dbcc125dc3  Pulling fs layer                                        0.3s
#    ⠹ f22640b02e8e  Pulling fs layer                                        0.3s
#    ⠹ d95b4d4c57a3  Pulling fs layer                                        0.3s
#    ⠹ 25c011418e0e  Pulling fs layer                                        0.3s
#    ⠹ 0a02f680d534  Pulling fs layer                                        0.3s
#    ✔ ecc81bf18836  Download complete                                       0.0s
# [+] up 1/11
#  ⠦ Image mongo:7.0 [⠀⠀⠀⠀⠀⠀⠀⠀⣿⣀] Pulling                                    4.7s
#    ⠸ 517f43312bfe  Pulling fs layer                                        0.4s
#    ⠸ 97e87ddfd658  Pulling fs layer                                        0.4s
#    ⠸ 2f6342326cfb  Pulling fs layer                                        0.4s
#    ⠸ a6dbcc125dc3  Pulling fs layer                                        0.4s
#    ⠸ f22640b02e8e  Pulling fs layer                                        0.4s
#    ⠸ d95b4d4c57a3  Pulling fs layer                                        0.4s
#    ⠸ 25c011418e0e  Pulling fs layer                                        0.4s
#    ⠸ 0a02f680d534  Pulling fs layer                                        0.4s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ⠋ 56a2e7643804  Downloading  1.049MB/3.227MB                            0.1s
# [+] up 2/11
#  ⠧ Image mongo:7.0 [⠀⠀⣿⠀⠀⠀⠀⠀⣿⣷] Pulling                                    4.8s
#    ⠼ 517f43312bfe  Pulling fs layer                                        0.5s
#    ⠼ 97e87ddfd658  Pulling fs layer                                        0.5s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ⠼ a6dbcc125dc3  Pulling fs layer                                        0.5s
#    ⠼ f22640b02e8e  Pulling fs layer                                        0.5s
#    ⠼ d95b4d4c57a3  Pulling fs layer                                        0.5s
#    ⠼ 25c011418e0e  Pulling fs layer                                        0.5s
#    ⠼ 0a02f680d534  Pulling fs layer                                        0.5s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ⠙ 56a2e7643804  Downloading  3.146MB/3.227MB                            0.2s
# [+] up 3/11
#  ⠇ Image mongo:7.0 [⠀⠀⣿⠀⠀⠀⠀⠀⣿⣿] Pulling                                    4.9s
#    ⠴ 517f43312bfe  Pulling fs layer                                        0.6s
#    ⠴ 97e87ddfd658  Pulling fs layer                                        0.6s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ⠴ a6dbcc125dc3  Pulling fs layer                                        0.6s
#    ⠴ f22640b02e8e  Pulling fs layer                                        0.6s
#    ⠴ d95b4d4c57a3  Pulling fs layer                                        0.6s
#    ⠴ 25c011418e0e  Pulling fs layer                                        0.6s
#    ⠴ 0a02f680d534  Pulling fs layer                                        0.6s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 4/11
#  ⠏ Image mongo:7.0 [⠀⠀⣿⠀⠀⣿⠀⠀⣿⣿] Pulling                                    5.0s
#    ⠦ 517f43312bfe  Downloading  1.049MB/27.38MB                            0.7s
#    ⠦ 97e87ddfd658  Pulling fs layer                                        0.7s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ⠦ a6dbcc125dc3  Pulling fs layer                                        0.7s
#    ⠦ f22640b02e8e  Pulling fs layer                                        0.7s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ⠦ 25c011418e0e  Pulling fs layer                                        0.7s
#    ⠦ 0a02f680d534  Pulling fs layer                                        0.7s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 4/11
#  ⠋ Image mongo:7.0 [⠀⠀⣿⠀⠀⣿⠀⠀⣿⣿] Pulling                                    5.1s
#    ⠧ 517f43312bfe  Downloading  1.049MB/27.38MB                            0.8s
#    ⠧ 97e87ddfd658  Pulling fs layer                                        0.8s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ⠧ a6dbcc125dc3  Pulling fs layer                                        0.8s
#    ⠧ f22640b02e8e  Pulling fs layer                                        0.8s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ⠧ 25c011418e0e  Pulling fs layer                                        0.8s
#    ⠧ 0a02f680d534  Pulling fs layer                                        0.8s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 4/11
#  ⠙ Image mongo:7.0 [⠀⠀⣿⠀⠀⣿⠀⠀⣿⣿] Pulling                                    5.2s
#    ⠇ 517f43312bfe  Downloading  2.097MB/27.38MB                            0.9s
#    ⠇ 97e87ddfd658  Pulling fs layer                                        0.9s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ⠇ a6dbcc125dc3  Pulling fs layer                                        0.9s
#    ⠇ f22640b02e8e  Pulling fs layer                                        0.9s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ⠇ 25c011418e0e  Pulling fs layer                                        0.9s
#    ⠇ 0a02f680d534  Pulling fs layer                                        0.9s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 4/11
#  ⠹ Image mongo:7.0 [⠀⠀⣿⠀⠀⣿⠀⠀⣿⣿] Pulling                                    5.3s
#    ⠏ 517f43312bfe  Downloading  3.146MB/27.38MB                            1.0s
#    ⠏ 97e87ddfd658  Pulling fs layer                                        1.0s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ⠏ a6dbcc125dc3  Pulling fs layer                                        1.0s
#    ⠏ f22640b02e8e  Downloading  1.049MB/240.6MB                            1.0s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ⠏ 25c011418e0e  Pulling fs layer                                        1.0s
#    ⠏ 0a02f680d534  Pulling fs layer                                        1.0s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 5/11
#  ⠸ Image mongo:7.0 [⠀⠀⣿⣿⠀⣿⠀⠀⣿⣿] Pulling                                    5.4s
#    ⠋ 517f43312bfe  Downloading  3.146MB/27.38MB                            1.1s
#    ⠋ 97e87ddfd658  Pulling fs layer                                        1.1s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠋ f22640b02e8e  Downloading  1.049MB/240.6MB                            1.1s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ⠋ 25c011418e0e  Pulling fs layer                                        1.1s
#    ⠋ 0a02f680d534  Pulling fs layer                                        1.1s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 6/11
#  ⠼ Image mongo:7.0 [⡀⣿⣿⣿⠀⣿⠀⠀⣿⣿] Pulling                                    5.5s
#    ⠙ 517f43312bfe  Downloading  4.194MB/27.38MB                            1.2s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠙ f22640b02e8e  Downloading  2.097MB/240.6MB                            1.2s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ⠙ 25c011418e0e  Pulling fs layer                                        1.2s
#    ⠙ 0a02f680d534  Pulling fs layer                                        1.2s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 6/11
#  ⠴ Image mongo:7.0 [⡀⣿⣿⣿⠀⣿⠀⠀⣿⣿] Pulling                                    5.6s
#    ⠹ 517f43312bfe  Downloading  4.194MB/27.38MB                            1.3s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠹ f22640b02e8e  Downloading  2.097MB/240.6MB                            1.3s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ⠹ 25c011418e0e  Pulling fs layer                                        1.3s
#    ⠹ 0a02f680d534  Pulling fs layer                                        1.3s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 6/11
#  ⠦ Image mongo:7.0 [⡀⣿⣿⣿⠀⣿⠀⠀⣿⣿] Pulling                                    5.7s
#    ⠸ 517f43312bfe  Downloading  4.194MB/27.38MB                            1.4s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠸ f22640b02e8e  Downloading  2.097MB/240.6MB                            1.4s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ⠸ 25c011418e0e  Pulling fs layer                                        1.4s
#    ⠸ 0a02f680d534  Pulling fs layer                                        1.4s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 6/11
#  ⠧ Image mongo:7.0 [⡀⣿⣿⣿⠀⣿⠀⠀⣿⣿] Pulling                                    5.8s
#    ⠼ 517f43312bfe  Downloading  5.243MB/27.38MB                            1.5s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠼ f22640b02e8e  Downloading  2.097MB/240.6MB                            1.5s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ⠼ 25c011418e0e  Pulling fs layer                                        1.5s
#    ⠼ 0a02f680d534  Pulling fs layer                                        1.5s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 6/11
#  ⠇ Image mongo:7.0 [⡀⣿⣿⣿⠀⣿⠀⠀⣿⣿] Pulling                                    5.9s
#    ⠴ 517f43312bfe  Downloading  6.291MB/27.38MB                            1.6s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠴ f22640b02e8e  Downloading  3.146MB/240.6MB                            1.6s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ⠴ 25c011418e0e  Pulling fs layer                                        1.6s
#    ⠴ 0a02f680d534  Pulling fs layer                                        1.6s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 6/11
#  ⠏ Image mongo:7.0 [⡀⣿⣿⣿⠀⣿⠀⠀⣿⣿] Pulling                                    6.0s
#    ⠦ 517f43312bfe  Downloading  6.291MB/27.38MB                            1.7s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠦ f22640b02e8e  Downloading  3.146MB/240.6MB                            1.7s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ⠦ 25c011418e0e  Pulling fs layer                                        1.7s
#    ⠦ 0a02f680d534  Pulling fs layer                                        1.7s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 6/11
#  ⠋ Image mongo:7.0 [⣀⣿⣿⣿⠀⣿⣦⠀⣿⣿] Pulling                                    6.1s
#    ⠧ 517f43312bfe  Downloading   7.34MB/27.38MB                            1.8s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠧ f22640b02e8e  Downloading  3.146MB/240.6MB                            1.8s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ⠧ 25c011418e0e  Downloading  1.049MB/1.482MB                            1.8s
#    ⠧ 0a02f680d534  Pulling fs layer                                        1.8s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 7/11
#  ⠙ Image mongo:7.0 [⣀⣿⣿⣿⠀⣿⣦⣿⣿⣿] 14.69MB / 272.7MB Pulling                  6.2s
#    ⠇ 517f43312bfe  Downloading   7.34MB/27.38MB                            1.9s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠇ f22640b02e8e  Downloading  3.146MB/240.6MB                            1.9s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ⠇ 25c011418e0e  Downloading  1.049MB/1.482MB                            1.9s
#    ✔ 0a02f680d534  Download complete                                       1.9s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 7/11
#  ⠹ Image mongo:7.0 [⣀⣿⣿⣿⠀⣿⣦⣿⣿⣿] 16.78MB / 272.7MB Pulling                  6.3s
#    ⠏ 517f43312bfe  Downloading  8.389MB/27.38MB                            2.0s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠏ f22640b02e8e  Downloading  4.194MB/240.6MB                            2.0s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ⠏ 25c011418e0e  Downloading  1.049MB/1.482MB                            2.0s
#    ✔ 0a02f680d534  Download complete                                       1.9s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 7/11
#  ⠸ Image mongo:7.0 [⣀⣿⣿⣿⠀⣿⣦⣿⣿⣿] 16.78MB / 272.7MB Pulling                  6.4s
#    ⠋ 517f43312bfe  Downloading  8.389MB/27.38MB                            2.1s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠋ f22640b02e8e  Downloading  4.194MB/240.6MB                            2.1s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ⠋ 25c011418e0e  Downloading  1.049MB/1.482MB                            2.1s
#    ✔ 0a02f680d534  Download complete                                       1.9s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 7/11
#  ⠼ Image mongo:7.0 [⣀⣿⣿⣿⠀⣿⣦⣿⣿⣿] 17.83MB / 272.7MB Pulling                  6.5s
#    ⠙ 517f43312bfe  Downloading  9.437MB/27.38MB                            2.2s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠙ f22640b02e8e  Downloading  4.194MB/240.6MB                            2.2s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ⠙ 25c011418e0e  Downloading  1.049MB/1.482MB                            2.2s
#    ✔ 0a02f680d534  Download complete                                       1.9s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 7/11
#  ⠴ Image mongo:7.0 [⣀⣿⣿⣿⠀⣿⣦⣿⣿⣿] 18.88MB / 272.7MB Pulling                  6.6s
#    ⠹ 517f43312bfe  Downloading  9.437MB/27.38MB                            2.3s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠹ f22640b02e8e  Downloading  5.243MB/240.6MB                            2.3s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ⠹ 25c011418e0e  Downloading  1.049MB/1.482MB                            2.3s
#    ✔ 0a02f680d534  Download complete                                       1.9s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 7/11
#  ⠦ Image mongo:7.0 [⣄⣿⣿⣿⠀⣿⣦⣿⣿⣿] 19.93MB / 272.7MB Pulling                  6.7s
#    ⠸ 517f43312bfe  Downloading  10.49MB/27.38MB                            2.4s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠸ f22640b02e8e  Downloading  5.243MB/240.6MB                            2.4s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ⠸ 25c011418e0e  Downloading  1.049MB/1.482MB                            2.4s
#    ✔ 0a02f680d534  Download complete                                       1.9s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 8/11
#  ⠧ Image mongo:7.0 [⣄⣿⣿⣿⠀⣿⣿⣿⣿⣿] 20.98MB / 272.7MB Pulling                  6.8s
#    ⠼ 517f43312bfe  Downloading  11.53MB/27.38MB                            2.5s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠼ f22640b02e8e  Downloading  5.243MB/240.6MB                            2.5s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ✔ 25c011418e0e  Download complete                                       2.5s
#    ✔ 0a02f680d534  Download complete                                       1.9s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 8/11
#  ⠇ Image mongo:7.0 [⣄⣿⣿⣿⠀⣿⣿⣿⣿⣿] 22.03MB / 272.7MB Pulling                  6.9s
#    ⠴ 517f43312bfe  Downloading  11.53MB/27.38MB                            2.6s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠴ f22640b02e8e  Downloading  6.291MB/240.6MB                            2.6s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ✔ 25c011418e0e  Download complete                                       2.5s
#    ✔ 0a02f680d534  Download complete                                       1.9s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 8/11
#  ⠏ Image mongo:7.0 [⣄⣿⣿⣿⠀⣿⣿⣿⣿⣿] 23.07MB / 272.7MB Pulling                  7.0s
#    ⠦ 517f43312bfe  Downloading  12.58MB/27.38MB                            2.7s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠦ f22640b02e8e  Downloading  6.291MB/240.6MB                            2.7s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ✔ 25c011418e0e  Download complete                                       2.5s
#    ✔ 0a02f680d534  Download complete                                       1.9s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 8/11
#  ⠋ Image mongo:7.0 [⣄⣿⣿⣿⠀⣿⣿⣿⣿⣿] 23.07MB / 272.7MB Pulling                  7.1s
#    ⠧ 517f43312bfe  Downloading  12.58MB/27.38MB                            2.8s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠧ f22640b02e8e  Downloading  6.291MB/240.6MB                            2.8s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ✔ 25c011418e0e  Download complete                                       2.5s
#    ✔ 0a02f680d534  Download complete                                       1.9s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 8/11
#  ⠙ Image mongo:7.0 [⣄⣿⣿⣿⠀⣿⣿⣿⣿⣿] 25.17MB / 272.7MB Pulling                  7.2s
#    ⠇ 517f43312bfe  Downloading  13.63MB/27.38MB                            2.9s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠇ f22640b02e8e  Downloading   7.34MB/240.6MB                            2.9s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ✔ 25c011418e0e  Download complete                                       2.5s
#    ✔ 0a02f680d534  Download complete                                       1.9s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 8/11
#  ⠹ Image mongo:7.0 [⣤⣿⣿⣿⠀⣿⣿⣿⣿⣿] 26.22MB / 272.7MB Pulling                  7.3s
#    ⠏ 517f43312bfe  Downloading  14.68MB/27.38MB                            3.0s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠏ f22640b02e8e  Downloading   7.34MB/240.6MB                            3.0s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ✔ 25c011418e0e  Download complete                                       2.5s
#    ✔ 0a02f680d534  Download complete                                       1.9s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 8/11
#  ⠸ Image mongo:7.0 [⣤⣿⣿⣿⠀⣿⣿⣿⣿⣿] 26.22MB / 272.7MB Pulling                  7.4s
#    ⠋ 517f43312bfe  Downloading  14.68MB/27.38MB                            3.1s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠋ f22640b02e8e  Downloading   7.34MB/240.6MB                            3.1s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ✔ 25c011418e0e  Download complete                                       2.5s
#    ✔ 0a02f680d534  Download complete                                       1.9s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 8/11
#  ⠼ Image mongo:7.0 [⣤⣿⣿⣿⠀⣿⣿⣿⣿⣿] 28.32MB / 272.7MB Pulling                  7.5s
#    ⠙ 517f43312bfe  Downloading  15.73MB/27.38MB                            3.2s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠙ f22640b02e8e  Downloading  8.389MB/240.6MB                            3.2s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ✔ 25c011418e0e  Download complete                                       2.5s
#    ✔ 0a02f680d534  Download complete                                       1.9s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 8/11
#  ⠴ Image mongo:7.0 [⣤⣿⣿⣿⠀⣿⣿⣿⣿⣿] 29.37MB / 272.7MB Pulling                  7.6s
#    ⠹ 517f43312bfe  Downloading  16.78MB/27.38MB                            3.3s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠹ f22640b02e8e  Downloading  8.389MB/240.6MB                            3.3s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ✔ 25c011418e0e  Download complete                                       2.5s
#    ✔ 0a02f680d534  Download complete                                       1.9s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 8/11
#  ⠦ Image mongo:7.0 [⣤⣿⣿⣿⠀⣿⣿⣿⣿⣿] 29.37MB / 272.7MB Pulling                  7.7s
#    ⠸ 517f43312bfe  Downloading  16.78MB/27.38MB                            3.4s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠸ f22640b02e8e  Downloading  8.389MB/240.6MB                            3.4s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ✔ 25c011418e0e  Download complete                                       2.5s
#    ✔ 0a02f680d534  Download complete                                       1.9s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 8/11
#  ⠧ Image mongo:7.0 [⣦⣿⣿⣿⠀⣿⣿⣿⣿⣿] 31.46MB / 272.7MB Pulling                  7.8s
#    ⠼ 517f43312bfe  Downloading  17.83MB/27.38MB                            3.5s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠼ f22640b02e8e  Downloading  9.437MB/240.6MB                            3.5s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ✔ 25c011418e0e  Download complete                                       2.5s
#    ✔ 0a02f680d534  Download complete                                       1.9s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 8/11
#  ⠇ Image mongo:7.0 [⣦⣿⣿⣿⠀⣿⣿⣿⣿⣿] 31.46MB / 272.7MB Pulling                  7.9s
#    ⠴ 517f43312bfe  Downloading  17.83MB/27.38MB                            3.6s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠴ f22640b02e8e  Downloading  9.437MB/240.6MB                            3.6s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ✔ 25c011418e0e  Download complete                                       2.5s
#    ✔ 0a02f680d534  Download complete                                       1.9s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 8/11
#  ⠏ Image mongo:7.0 [⣦⣿⣿⣿⠀⣿⣿⣿⣿⣿] 32.51MB / 272.7MB Pulling                  8.0s
#    ⠦ 517f43312bfe  Downloading  18.87MB/27.38MB                            3.7s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠦ f22640b02e8e  Downloading  9.437MB/240.6MB                            3.7s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ✔ 25c011418e0e  Download complete                                       2.5s
#    ✔ 0a02f680d534  Download complete                                       1.9s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 8/11
#  ⠋ Image mongo:7.0 [⣦⣿⣿⣿⠀⣿⣿⣿⣿⣿] 34.61MB / 272.7MB Pulling                  8.1s
#    ⠧ 517f43312bfe  Downloading  19.92MB/27.38MB                            3.8s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠧ f22640b02e8e  Downloading  10.49MB/240.6MB                            3.8s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ✔ 25c011418e0e  Download complete                                       2.5s
#    ✔ 0a02f680d534  Download complete                                       1.9s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 8/11
#  ⠙ Image mongo:7.0 [⣦⣿⣿⣿⠀⣿⣿⣿⣿⣿] 34.61MB / 272.7MB Pulling                  8.2s
#    ⠇ 517f43312bfe  Downloading  19.92MB/27.38MB                            3.9s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠇ f22640b02e8e  Downloading  10.49MB/240.6MB                            3.9s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ✔ 25c011418e0e  Download complete                                       2.5s
#    ✔ 0a02f680d534  Download complete                                       1.9s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 8/11
#  ⠹ Image mongo:7.0 [⣶⣿⣿⣿⠀⣿⣿⣿⣿⣿] 35.66MB / 272.7MB Pulling                  8.3s
#    ⠏ 517f43312bfe  Downloading  20.97MB/27.38MB                            4.0s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠏ f22640b02e8e  Downloading  10.49MB/240.6MB                            4.0s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ✔ 25c011418e0e  Download complete                                       2.5s
#    ✔ 0a02f680d534  Download complete                                       1.9s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 8/11
#  ⠸ Image mongo:7.0 [⣶⣿⣿⣿⠀⣿⣿⣿⣿⣿] 37.75MB / 272.7MB Pulling                  8.4s
#    ⠋ 517f43312bfe  Downloading  22.02MB/27.38MB                            4.1s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠋ f22640b02e8e  Downloading  11.53MB/240.6MB                            4.1s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ✔ 25c011418e0e  Download complete                                       2.5s
#    ✔ 0a02f680d534  Download complete                                       1.9s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 8/11
#  ⠼ Image mongo:7.0 [⣶⣿⣿⣿⠀⣿⣿⣿⣿⣿] 37.75MB / 272.7MB Pulling                  8.5s
#    ⠙ 517f43312bfe  Downloading  22.02MB/27.38MB                            4.2s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠙ f22640b02e8e  Downloading  11.53MB/240.6MB                            4.2s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ✔ 25c011418e0e  Download complete                                       2.5s
#    ✔ 0a02f680d534  Download complete                                       1.9s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 8/11
#  ⠴ Image mongo:7.0 [⣶⣿⣿⣿⠀⣿⣿⣿⣿⣿]  38.8MB / 272.7MB Pulling                  8.6s
#    ⠹ 517f43312bfe  Downloading  23.07MB/27.38MB                            4.3s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠹ f22640b02e8e  Downloading  11.53MB/240.6MB                            4.3s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ✔ 25c011418e0e  Download complete                                       2.5s
#    ✔ 0a02f680d534  Download complete                                       1.9s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 8/11
#  ⠦ Image mongo:7.0 [⣶⣿⣿⣿⠀⣿⣿⣿⣿⣿]  38.8MB / 272.7MB Pulling                  8.7s
#    ⠸ 517f43312bfe  Downloading  23.07MB/27.38MB                            4.4s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠸ f22640b02e8e  Downloading  11.53MB/240.6MB                            4.4s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ✔ 25c011418e0e  Download complete                                       2.5s
#    ✔ 0a02f680d534  Download complete                                       1.9s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 8/11
#  ⠧ Image mongo:7.0 [⣷⣿⣿⣿⠀⣿⣿⣿⣿⣿]  40.9MB / 272.7MB Pulling                  8.8s
#    ⠼ 517f43312bfe  Downloading  24.12MB/27.38MB                            4.5s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠼ f22640b02e8e  Downloading  12.58MB/240.6MB                            4.5s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ✔ 25c011418e0e  Download complete                                       2.5s
#    ✔ 0a02f680d534  Download complete                                       1.9s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 8/11
#  ⠇ Image mongo:7.0 [⣷⣿⣿⣿⠀⣿⣿⣿⣿⣿] 41.95MB / 272.7MB Pulling                  8.9s
#    ⠴ 517f43312bfe  Downloading  25.17MB/27.38MB                            4.6s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠴ f22640b02e8e  Downloading  12.58MB/240.6MB                            4.6s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ✔ 25c011418e0e  Download complete                                       2.5s
#    ✔ 0a02f680d534  Download complete                                       1.9s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 8/11
#  ⠏ Image mongo:7.0 [⣷⣿⣿⣿⠀⣿⣿⣿⣿⣿]    43MB / 272.7MB Pulling                  9.0s
#    ⠦ 517f43312bfe  Downloading  25.17MB/27.38MB                            4.7s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠦ f22640b02e8e  Downloading  13.63MB/240.6MB                            4.7s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ✔ 25c011418e0e  Download complete                                       2.5s
#    ✔ 0a02f680d534  Download complete                                       1.9s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 8/11
#  ⠋ Image mongo:7.0 [⣷⣿⣿⣿⠀⣿⣿⣿⣿⣿] 44.05MB / 272.7MB Pulling                  9.1s
#    ⠧ 517f43312bfe  Downloading  26.21MB/27.38MB                            4.8s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠧ f22640b02e8e  Downloading  13.63MB/240.6MB                            4.8s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ✔ 25c011418e0e  Download complete                                       2.5s
#    ✔ 0a02f680d534  Download complete                                       1.9s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 8/11
#  ⠙ Image mongo:7.0 [⣷⣿⣿⣿⠀⣿⣿⣿⣿⣿] 45.09MB / 272.7MB Pulling                  9.2s
#    ⠇ 517f43312bfe  Downloading  27.26MB/27.38MB                            4.9s
#    ✔ 97e87ddfd658  Download complete                                       1.2s
#    ✔ 2f6342326cfb  Download complete                                       0.5s
#    ✔ a6dbcc125dc3  Download complete                                       1.0s
#    ⠇ f22640b02e8e  Downloading  13.63MB/240.6MB                            4.9s
#    ✔ d95b4d4c57a3  Download complete                                       0.7s
#    ✔ 25c011418e0e  Download complete                                       2.5s
#    ✔ 0a02f680d534  Download complete                                       1.9s
#    ✔ ecc81bf18836  Download complete                                       0.0s
#    ✔ 56a2e7643804  Download complete                                       0.2s
# [+] up 8/11
#  ⠹ Image mongo:7.0 [⣿⣿⣿⣿⠀⣿⣿⣿⣿⣿] 46.26MB / 272.7MB Pulling                  9.3s
#    ⠏ 517f43312bfe  Extracting 1 s                                          5.0s
# ...
# [+] up 12/15
#  ✔ Image mongo:7.0                       Pulled                           38.3s
#    ✔ 517f43312bfe                        Pull complete                     5.3s
#    ✔ 97e87ddfd658                        Pull complete                     1.2s
#    ✔ 2f6342326cfb                        Pull complete                     0.5s
#    ✔ a6dbcc125dc3                        Pull complete                     1.0s
#    ✔ f22640b02e8e                        Pull complete                    34.0s
#    ✔ d95b4d4c57a3                        Pull complete                     0.7s
#    ✔ 25c011418e0e                        Pull complete                     2.5s
#    ✔ 0a02f680d534                        Pull complete                     1.9s
#    ✔ ecc81bf18836                        Download complete                 0.0s
#    ✔ 56a2e7643804                        Download complete                 0.2s
#  ✔ Network mongodb-cluster_mongo-cluster Created                           0.0s
#  ⠴ Container mongodb-node-1              Waiting                           6.7s
#  ⠼ Container mongodb-node-2              Waiting                           6.5s
#  ⠼ Container mongodb-node-3              Waiting                           6.4s
# [+] up 12/15
#  ✔ Image mongo:7.0                       Pulled                           38.3s
#    ✔ 517f43312bfe                        Pull complete                     5.3s
#    ✔ 97e87ddfd658                        Pull complete                     1.2s
#    ✔ 2f6342326cfb                        Pull complete                     0.5s
#    ✔ a6dbcc125dc3                        Pull complete                     1.0s
#    ✔ f22640b02e8e                        Pull complete                    34.0s
#    ✔ d95b4d4c57a3                        Pull complete                     0.7s
#    ✔ 25c011418e0e                        Pull complete                     2.5s
#    ✔ 0a02f680d534                        Pull complete                     1.9s
#    ✔ ecc81bf18836                        Download complete                 0.0s
#    ✔ 56a2e7643804                        Download complete                 0.2s
#  ✔ Network mongodb-cluster_mongo-cluster Created                           0.0s
#  ⠦ Container mongodb-node-1              Waiting                           6.8s
#  ⠴ Container mongodb-node-2              Waiting                           6.6s
#  ⠴ Container mongodb-node-3              Waiting                           6.5s
# [+] up 12/15
#  ✔ Image mongo:7.0                       Pulled                           38.3s
#    ✔ 517f43312bfe                        Pull complete                     5.3s
#    ✔ 97e87ddfd658                        Pull complete                     1.2s
#    ✔ 2f6342326cfb                        Pull complete                     0.5s
#    ✔ a6dbcc125dc3                        Pull complete                     1.0s
#    ✔ f22640b02e8e                        Pull complete                    34.0s
#    ✔ d95b4d4c57a3                        Pull complete                     0.7s
#    ✔ 25c011418e0e                        Pull complete                     2.5s
#    ✔ 0a02f680d534                        Pull complete                     1.9s
#    ✔ ecc81bf18836                        Download complete                 0.0s
#    ✔ 56a2e7643804                        Download complete                 0.2s
#  ✔ Network mongodb-cluster_mongo-cluster Created                           0.0s
#  ⠧ Container mongodb-node-1              Waiting                           6.9s
#  ⠦ Container mongodb-node-2              Waiting                           6.7s
#  ⠦ Container mongodb-node-3              Waiting                           6.6s
# [+] up 12/15
#  ✔ Image mongo:7.0                       Pulled                           38.3s
#    ✔ 517f43312bfe                        Pull complete                     5.3s
#    ✔ 97e87ddfd658                        Pull complete                     1.2s
#    ✔ 2f6342326cfb                        Pull complete                     0.5s
#    ✔ a6dbcc125dc3                        Pull complete                     1.0s
#    ✔ f22640b02e8e                        Pull complete                    34.0s
#    ✔ d95b4d4c57a3                        Pull complete                     0.7s
#    ✔ 25c011418e0e                        Pull complete                     2.5s
#    ✔ 0a02f680d534                        Pull complete                     1.9s
#    ✔ ecc81bf18836                        Download complete                 0.0s
#    ✔ 56a2e7643804                        Download complete                 0.2s
#  ✔ Network mongodb-cluster_mongo-cluster Created                           0.0s
#  ⠇ Container mongodb-node-1              Waiting                           7.0s
#  ⠧ Container mongodb-node-2              Waiting                           6.8s
#  ⠧ Container mongodb-node-3              Waiting                           6.7s
# [+] up 12/15
#  ✔ Image mongo:7.0                       Pulled                           38.3s
#    ✔ 517f43312bfe                        Pull complete                     5.3s
#    ✔ 97e87ddfd658                        Pull complete                     1.2s
#    ✔ 2f6342326cfb                        Pull complete                     0.5s
#    ✔ a6dbcc125dc3                        Pull complete                     1.0s
#    ✔ f22640b02e8e                        Pull complete                    34.0s
#    ✔ d95b4d4c57a3                        Pull complete                     0.7s
#    ✔ 25c011418e0e                        Pull complete                     2.5s
#    ✔ 0a02f680d534                        Pull complete                     1.9s
#    ✔ ecc81bf18836                        Download complete                 0.0s
#    ✔ 56a2e7643804                        Download complete                 0.2s
#  ✔ Network mongodb-cluster_mongo-cluster Created                           0.0s
#  ⠏ Container mongodb-node-1              Waiting                           7.1s
#  ⠇ Container mongodb-node-2              Waiting                           6.9s
#  ⠇ Container mongodb-node-3              Waiting                           6.8s
# [+] up 12/15
#  ✔ Image mongo:7.0                       Pulled                           38.3s
#    ✔ 517f43312bfe                        Pull complete                     5.3s
#    ✔ 97e87ddfd658                        Pull complete                     1.2s
#    ✔ 2f6342326cfb                        Pull complete                     0.5s
#    ✔ a6dbcc125dc3                        Pull complete                     1.0s
#    ✔ f22640b02e8e                        Pull complete                    34.0s
#    ✔ d95b4d4c57a3                        Pull complete                     0.7s
#    ✔ 25c011418e0e                        Pull complete                     2.5s
#    ✔ 0a02f680d534                        Pull complete                     1.9s
#    ✔ ecc81bf18836                        Download complete                 0.0s
#    ✔ 56a2e7643804                        Download complete                 0.2s
#  ✔ Network mongodb-cluster_mongo-cluster Created                           0.0s
#  ⠋ Container mongodb-node-1              Waiting                           7.2s
#  ⠏ Container mongodb-node-2              Waiting                           7.0s
#  ⠏ Container mongodb-node-3              Waiting                           6.9s
# [+] up 12/15
#  ✔ Image mongo:7.0                       Pulled                           38.3s
#    ✔ 517f43312bfe                        Pull complete                     5.3s
#    ✔ 97e87ddfd658                        Pull complete                     1.2s
#    ✔ 2f6342326cfb                        Pull complete                     0.5s
#    ✔ a6dbcc125dc3                        Pull complete                     1.0s
#    ✔ f22640b02e8e                        Pull complete                    34.0s
#    ✔ d95b4d4c57a3                        Pull complete                     0.7s
#    ✔ 25c011418e0e                        Pull complete                     2.5s
#    ✔ 0a02f680d534                        Pull complete                     1.9s
#    ✔ ecc81bf18836                        Download complete                 0.0s
#    ✔ 56a2e7643804                        Download complete                 0.2s
#  ✔ Network mongodb-cluster_mongo-cluster Created                           0.0s
#  ⠙ Container mongodb-node-1              Waiting                           7.3s
#  ⠋ Container mongodb-node-2              Waiting                           7.1s
#  ⠋ Container mongodb-node-3              Waiting                           7.0s
# [+] up 12/15
#  ✔ Image mongo:7.0                       Pulled                           38.3s
#    ✔ 517f43312bfe                        Pull complete                     5.3s
#    ✔ 97e87ddfd658                        Pull complete                     1.2s
#    ✔ 2f6342326cfb                        Pull complete                     0.5s
#    ✔ a6dbcc125dc3                        Pull complete                     1.0s
#    ✔ f22640b02e8e                        Pull complete                    34.0s
#    ✔ d95b4d4c57a3                        Pull complete                     0.7s
#    ✔ 25c011418e0e                        Pull complete                     2.5s
#    ✔ 0a02f680d534                        Pull complete                     1.9s
#    ✔ ecc81bf18836                        Download complete                 0.0s
#    ✔ 56a2e7643804                        Download complete                 0.2s
#  ✔ Network mongodb-cluster_mongo-cluster Created                           0.0s
#  ⠹ Container mongodb-node-1              Waiting                           7.4s
#  ⠙ Container mongodb-node-2              Waiting                           7.2s
#  ⠙ Container mongodb-node-3              Waiting                           7.1s
# [+] up 12/15
#  ✔ Image mongo:7.0                       Pulled                           38.3s
#    ✔ 517f43312bfe                        Pull complete                     5.3s
#    ✔ 97e87ddfd658                        Pull complete                     1.2s
#    ✔ 2f6342326cfb                        Pull complete                     0.5s
#    ✔ a6dbcc125dc3                        Pull complete                     1.0s
#    ✔ f22640b02e8e                        Pull complete                    34.0s
#    ✔ d95b4d4c57a3                        Pull complete                     0.7s
#    ✔ 25c011418e0e                        Pull complete                     2.5s
#    ✔ 0a02f680d534                        Pull complete                     1.9s
#    ✔ ecc81bf18836                        Download complete                 0.0s
#    ✔ 56a2e7643804                        Download complete                 0.2s
#  ✔ Network mongodb-cluster_mongo-cluster Created                           0.0s
#  ⠸ Container mongodb-node-1              Waiting                           7.5s
#  ⠹ Container mongodb-node-2              Waiting                           7.3s
#  ⠹ Container mongodb-node-3              Waiting                           7.2s
# [+] up 12/15
#  ✔ Image mongo:7.0                       Pulled                           38.3s
#    ✔ 517f43312bfe                        Pull complete                     5.3s
#    ✔ 97e87ddfd658                        Pull complete                     1.2s
#    ✔ 2f6342326cfb                        Pull complete                     0.5s
#    ✔ a6dbcc125dc3                        Pull complete                     1.0s
#    ✔ f22640b02e8e                        Pull complete                    34.0s
#    ✔ d95b4d4c57a3                        Pull complete                     0.7s
#    ✔ 25c011418e0e                        Pull complete                     2.5s
#    ✔ 0a02f680d534                        Pull complete                     1.9s
#    ✔ ecc81bf18836                        Download complete                 0.0s
#    ✔ 56a2e7643804                        Download complete                 0.2s
#  ✔ Network mongodb-cluster_mongo-cluster Created                           0.0s
#  ⠼ Container mongodb-node-1              Waiting                           7.6s
#  ⠸ Container mongodb-node-2              Waiting                           7.4s
#  ⠸ Container mongodb-node-3              Waiting                           7.3s
# [+] up 12/15
#  ✔ Image mongo:7.0                       Pulled                           38.3s
#    ✔ 517f43312bfe                        Pull complete                     5.3s
#    ✔ 97e87ddfd658                        Pull complete                     1.2s
#    ✔ 2f6342326cfb                        Pull complete                     0.5s
#    ✔ a6dbcc125dc3                        Pull complete                     1.0s
#    ✔ f22640b02e8e                        Pull complete                    34.0s
#    ✔ d95b4d4c57a3                        Pull complete                     0.7s
#    ✔ 25c011418e0e                        Pull complete                     2.5s
#    ✔ 0a02f680d534                        Pull complete                     1.9s
#    ✔ ecc81bf18836                        Download complete                 0.0s
#    ✔ 56a2e7643804                        Download complete                 0.2s
#  ✔ Network mongodb-cluster_mongo-cluster Created                           0.0s
#  ⠴ Container mongodb-node-1              Waiting                           7.7s
#  ⠼ Container mongodb-node-2              Waiting                           7.5s
#  ⠼ Container mongodb-node-3              Waiting                           7.4s
# [+] up 12/15
#  ✔ Image mongo:7.0                       Pulled                           38.3s
#    ✔ 517f43312bfe                        Pull complete                     5.3s
#    ✔ 97e87ddfd658                        Pull complete                     1.2s
#    ✔ 2f6342326cfb                        Pull complete                     0.5s
#    ✔ a6dbcc125dc3                        Pull complete                     1.0s
#    ✔ f22640b02e8e                        Pull complete                    34.0s
#    ✔ d95b4d4c57a3                        Pull complete                     0.7s
#    ✔ 25c011418e0e                        Pull complete                     2.5s
#    ✔ 0a02f680d534                        Pull complete                     1.9s
#    ✔ ecc81bf18836                        Download complete                 0.0s
#    ✔ 56a2e7643804                        Download complete                 0.2s
#  ✔ Network mongodb-cluster_mongo-cluster Created                           0.0s
#  ⠦ Container mongodb-node-1              Waiting                           7.8s
#  ⠴ Container mongodb-node-2              Waiting                           7.6s
#  ⠴ Container mongodb-node-3              Waiting                           7.5s
# [+] up 15/15
#  ✔ Image mongo:7.0                       Pulled                           38.3s
#    ✔ 517f43312bfe                        Pull complete                     5.3s
#    ✔ 97e87ddfd658                        Pull complete                     1.2s
#    ✔ 2f6342326cfb                        Pull complete                     0.5s
#    ✔ a6dbcc125dc3                        Pull complete                     1.0s
#    ✔ f22640b02e8e                        Pull complete                    34.0s
#    ✔ d95b4d4c57a3                        Pull complete                     0.7s
#    ✔ 25c011418e0e                        Pull complete                     2.5s
#    ✔ 0a02f680d534                        Pull complete                     1.9s
#    ✔ ecc81bf18836                        Download complete                 0.0s
#    ✔ 56a2e7643804                        Download complete                 0.2s
#  ✔ Network mongodb-cluster_mongo-cluster Created                           0.0s
#  ✔ Container mongodb-node-1              Healthy                           7.8s
#  ✔ Container mongodb-node-2              Healthy                           7.6s
#  ✔ Container mongodb-node-3              Healthy                           7.6s

# %%
import time
from pymongo import MongoClient
from pymongo.errors import OperationFailure

MONGODB_PRIMARY_SELECTION_TIMEOUT_SECONDS = 30
client_options = {"directConnection": True, "serverSelectionTimeoutMS": 5000}

init_client = MongoClient(
    f"mongodb://{MONGO_INITDB_ROOT_USERNAME}:{MONGO_INITDB_ROOT_PASSWORD}@{MONGODB_NODE_HOSTNAMES[0]}:{MONGODB_NODE_PORTS[0]}/",
    **client_options,
)
try:
    print(f"🚀 Initializing Replica Set: '{MONGODB_REPLICA_SET}'")
    init_client.admin.command(
        "replSetInitiate",
        {
            "_id": MONGODB_REPLICA_SET,
            "members": [
                {
                    "_id": i,
                    "host": f"{MONGODB_NODE_HOSTNAMES[i]}:{MONGODB_NODE_PORTS[i]}",
                }
                for i in range(MONGODB_TOTAL_NODES)
            ],
        },
    )
    print("✅ Initiation command accepted.")
except OperationFailure as e:
    if "already initialized" in str(e).lower():
        print("⚠️ Cluster is already initiated. Verifying health...")
    else:
        raise

start_time = time.time()
primary_found = False
print(f"⏳ Waiting for Primary (Timeout: {MONGODB_PRIMARY_SELECTION_TIMEOUT_SECONDS}s)")
while time.time() - start_time < MONGODB_PRIMARY_SELECTION_TIMEOUT_SECONDS:
    for i in range(MONGODB_TOTAL_NODES):
        try:
            with MongoClient(
                f"mongodb://{MONGODB_NODE_HOSTNAMES[i]}:{MONGODB_NODE_PORTS[i]}/",
                **client_options,
            ) as node_check:
                res = node_check.admin.command("hello")
                if res.get("isWritablePrimary") or res.get("ismaster"):
                    primary_found = True
                    elapsed = round(time.time() - start_time, 2)
                    print(
                        f"\n🌟 Primary Elected: {res.get('me')} (Found at {MONGODB_NODE_HOSTNAMES[i]}:{MONGODB_NODE_PORTS[i]} in {elapsed}s)"
                    )
                    break
        except Exception:
            continue
    if primary_found:
        break
    print(f"Still electing... [{int(time.time() - start_time)}s]", end="\r")
    time.sleep(0.05)

if not primary_found:
    status = init_client.admin.command("replSetGetStatus")
    print("\n❌ Timeout reached. Current Node States:")
    for m in status.get("members", []):
        print(f" - {m['name']}: {m['stateStr']}")
    raise TimeoutError("Replica Set failed to elect a Primary.")
else:
    status = init_client.admin.command("replSetGetStatus")
    print(f"\nCluster '{MONGODB_REPLICA_SET}' Status Summary:")
    for m in status["members"]:
        icon = "🟢" if m["health"] == 1 else "🔴"
        print(f"{icon} {m['name']:<35} | {m['stateStr']:<10}")
# Out:
# 🚀 Initializing Replica Set: 'replica_set_0'
# ✅ Initiation command accepted.
# ⏳ Waiting for Primary (Timeout: 30s)
# Still electing... [11s]
# 🌟 Primary Elected: mongodb-node-1.lvilla17.vpn.itam.mx:27011 (Found at mongodb-node-1.lvilla17.vpn.itam.mx:27011 in 11.77s)
#
# Cluster 'replica_set_0' Status Summary:
# 🟢 mongodb-node-1.lvilla17.vpn.itam.mx:27011 | PRIMARY
# 🟢 mongodb-node-2.lvilla17.vpn.itam.mx:27012 | SECONDARY
# 🟢 mongodb-node-3.lvilla17.vpn.itam.mx:27013 | SECONDARY
